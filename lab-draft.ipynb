# %% [markdown]
# # Title

# %% [markdown]
# ---
# embed-resources: true
# echo: false
# ---

# %% [markdown]
# ## Introduction

# %% [markdown]
# ## Methods

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import StratifiedKFold, cross_val_predict
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_recall_curve, precision_score, recall_score
from sklearn.base import BaseEstimator, ClassifierMixin
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

import joblib

# %% [markdown]
# ### Data

# %%
swing_train = pd.read_parquet(
    "https://lab.cs307.org/swing/data/swing-train.parquet",
)
swing_test = pd.read_parquet(
    "https://lab.cs307.org/swing/data/swing-test.parquet",
)
print (swing_train.head())
print (swing_test.head())
# Out:
#       pitch_name  release_extension  release_pos_x  release_pos_y  \
# 0         Cutter                6.6          -2.76          53.86
# 1       Changeup                6.8          -2.87          53.74
# 2       Changeup                6.7          -2.83          53.82
# 3  Knuckle Curve                6.7          -2.70          53.78
# 4         Cutter                6.7          -2.64          53.83
#
#    release_pos_z  release_speed  release_spin_rate  spin_axis  plate_x  \
# 0           5.81           92.6             2376.0      195.0    -0.09
# 1           5.66           86.3             1511.0      226.0    -1.47
# 2           5.68           87.9             1570.0      224.0    -1.52
# 3           5.78           82.4             2398.0       32.0     0.20
# 4           5.81           91.0             2427.0      189.0     0.89
#
#    plate_z  ...  balls  strikes  on_3b  on_2b  on_1b  outs_when_up  stand  \
# 0     2.79  ...      3        1      0      0      0             1      L
# 1     1.84  ...      2        1      0      0      0             1      L
# 2     2.38  ...      1        1      0      0      0             1      L
# 3     1.04  ...      1        0      0      0      0             1      L
# 4     1.65  ...      0        0      0      0      0             1      L
#
#    sz_top sz_bot  swing
# 0    3.15   1.52      1
# 1    3.13   1.56      0
# 2    3.12   1.51      0
# 3    3.15   1.52      1
# 4    3.12   1.51      0
#
# [5 rows x 22 columns]
#         pitch_name  release_extension  release_pos_x  release_pos_y  \
# 0  4-Seam Fastball                6.9          -2.73          53.65
# 1  4-Seam Fastball                6.8          -2.56          53.67
# 2  4-Seam Fastball                6.7          -2.79          53.79
# 3  4-Seam Fastball                6.8          -2.71          53.71
# 4  4-Seam Fastball                6.6          -2.82          53.85
#
#    release_pos_z  release_speed  release_spin_rate  spin_axis  plate_x  \
# 0           5.93           93.7               2267        203    -0.44
# 1           5.95           93.8               2311        198     0.15
# 2           5.87           93.8               2238        209    -1.69
# 3           5.91           93.6               2208        199    -0.35
# 4           5.96           91.7               2145        201    -0.40
#
#    plate_z  ...  balls  strikes  on_3b  on_2b  on_1b  outs_when_up  stand  \
# 0     2.11  ...      2        1      0      0      1             0      R
# 1     3.02  ...      2        0      0      0      1             0      R
# 2     2.78  ...      1        0      0      0      1             0      R
# 3     4.57  ...      0        0      0      0      1             0      R
# 4     2.59  ...      1        2      0      0      0             0      R
#
#    sz_top sz_bot  swing
# 0    3.59   1.73      1
# 1    3.59   1.73      1
# 2    3.71   1.78      0
# 3    3.71   1.78      0
# 4    3.26   1.53      1
#
# [5 rows x 22 columns]

# %%
# create X and y for train
X_train = swing_train.drop("swing", axis=1)
y_train = swing_train["swing"]

# create X and y for test
X_test = swing_test.drop("swing", axis=1)
y_test = swing_test["swing"]

# %%
# echo: true
# summary statistics

n_samples, n_features = X_train.shape
print(n_samples)
print(n_features)

all = y_train.mean()
print(all)
# Out:
# 2663
# 21
# 0.47728126173488544

# %%
# pitch type
pitch = (swing_train.groupby('pitch_name')['swing'].mean().sort_index())
print(pitch)
# Out:
# pitch_name
# 4-Seam Fastball    0.470904
# Changeup           0.536313
# Cutter             0.451477
# Knuckle Curve      0.462875
# Slider             0.496124
# Name: swing, dtype: float64

# %% [markdown]
# ### Models

# %%
categorical = ["pitch_name", "stand"]
numerical = X_train.select_dtypes(include=['int64', 'float64']).columns

# much simpler version
preprocessing = ColumnTransformer([
    ("numerical", StandardScaler(), numerical),
    ("categorical", OneHotEncoder(), categorical)
])

# %% [markdown]
# ## Results

# %%
# report model metrics

# %%
# summary figure

# %%
# serialize model
import joblib
joblib.dump(rf, "fraud.joblib")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 # serialize model
#       2 import joblib
# ----> 3 joblib.dump(rf, "fraud.joblib")
#
# NameError: name 'rf' is not defined

# %% [markdown]
# ## Discussion
